# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)

# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("NLP_Data_Cleanup").getOrCreate()

# %%
df=spark.read.csv('/content/sample_data/test.csv', header=True)
df=df.select("id","statement","speaker")
df=df.dropna()
df.show(10)
# Out:
# +--------------------+--------------------+------------------+
# |                  id|           statement|           speaker|
# +--------------------+--------------------+------------------+
# |               21750|"Three doctors fr...|the gateway pundit|
# |               18173|Say Joe Biden is ...|    facebook posts|
# |                   "|                  24|               245|
# |               22673|A photo shows Pre...|       viral image|
# |                9897|It will cost $50,...|     stuart varney|
# |                3855|The Federal Regis...|      randy forbes|
# |Forbes previously...|                NULL|              NULL|
# |Forbes received a...|             in 1974|         in 1977."|
# |                2884|"Following the 20...|          abortion|
# |               18102|"America was the ...|    facebook posts|
# +--------------------+--------------------+------------------+
# only showing top 10 rows

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# **Tokenization**

# %%
from nltk.tokenize import sent_tokenize
from pyspark.sql import functions as F
from pyspark.sql.functions import udf
from pyspark.sql.types import ArrayType, StringType

def tokenize_sentences(text):
  try:
    return sent_tokenize(text)
  except:
    return []

udf_tokenize_sentences = udf(tokenize_sentences, ArrayType(StringType()))
df = df.withColumn("sentence",udf_tokenize_sentences(F.col("statement")))
df.select('statement','sentence').show(10, truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------+
# |statement                                                                                                                                      |sentence                                                                                                                                         |
# +-----------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------+
# |"Three doctors from the same hospital 'die suddenly' in the same week,"" after the hospital mandated a fourth COVID-19 vaccine for employees." |["Three doctors from the same hospital 'die suddenly' in the same week,"" after the hospital mandated a fourth COVID-19 vaccine for employees."] |
# |Say Joe Biden is a pedophile.                                                                                                                  |[Say Joe Biden is a pedophile.]                                                                                                                  |
# |24                                                                                                                                             |[24]                                                                                                                                             |
# |A photo shows President Joe Biden and Ukrainian President Volodymyr Zelenskyy holding hands.                                                   |[A photo shows President Joe Biden and Ukrainian President Volodymyr Zelenskyy holding hands.]                                                   |
# |It will cost $50,000 per enrollee in Obamacare over the next 10 years.                                                                         |[It will cost $50,000 per enrollee in Obamacare over the next 10 years.]                                                                         |
# |The Federal Register - which houses all Washington regulations - is 34,000 pages in length and weighs in at more than 340 pounds.              |[The Federal Register - which houses all Washington regulations - is 34,000 pages in length and weighs in at more than 340 pounds.]              |
# |NULL                                                                                                                                           |[]                                                                                                                                               |
# | in 1974                                                                                                                                       |[ in 1974]                                                                                                                                       |
# |"Following the 2009 session,"" Texas House Speaker Joe Straus ""was acknowledged and 'thanked' for his 'tireless efforts' by Planned Parenthood|["Following the 2009 session,"" Texas House Speaker Joe Straus ""was acknowledged and 'thanked' for his 'tireless efforts' by Planned Parenthood]|
# |"America was the ONLY country that ended"" slavery"                                                                                            |["America was the ONLY country that ended"" slavery"]                                                                                            |
# +-----------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# **Removing Stop words**

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
  try:
    for i in range(len(text)):
      words=nltk.word_tokenize(text[i])
      words_without_stopword=[word for word in words if word.lower() not in stop_words]
      text[i]=''.join(words_without_stopword)
    return words_without_stopword
  except:
    return []

udf_remove_stopwords = udf(remove_stopwords, ArrayType(StringType()))

df = df.withColumn("filtered_sentence",udf_remove_stopwords(F.col("sentence")))


def remove_strings(text):
  try:
    for i in text:
      if len(i)<2:
        text.remove(i)
    return text
  except:
    return []

udf_remove_strings = udf(remove_strings, ArrayType(StringType()))

df = df.withColumn("filtered_sentence_1",udf_remove_strings(F.col("filtered_sentence")))
df.select("sentence","filtered_sentence","filtered_sentence_1").show(10, truncate=False)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# +-------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------+
# |sentence                                                                                                                                         |filtered_sentence                                                                                                                                           |filtered_sentence_1                                                                                                                                |
# +-------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------+
# |["Three doctors from the same hospital 'die suddenly' in the same week,"" after the hospital mandated a fourth COVID-19 vaccine for employees."] |[``, Three, doctors, hospital, 'die, suddenly, ', week, ,, '', '', hospital, mandated, fourth, COVID-19, vaccine, employees, ., '']                         |[``, Three, doctors, hospital, 'die, suddenly, week, '', '', hospital, mandated, fourth, COVID-19, vaccine, employees, '']                         |
# |[Say Joe Biden is a pedophile.]                                                                                                                  |[Say, Joe, Biden, pedophile, .]                                                                                                                             |[Say, Joe, Biden, pedophile]                                                                                                                       |
# |[24]                                                                                                                                             |[24]                                                                                                                                                        |[24]                                                                                                                                               |
# |[A photo shows President Joe Biden and Ukrainian President Volodymyr Zelenskyy holding hands.]                                                   |[photo, shows, President, Joe, Biden, Ukrainian, President, Volodymyr, Zelenskyy, holding, hands, .]                                                        |[photo, shows, President, Joe, Biden, Ukrainian, President, Volodymyr, Zelenskyy, holding, hands]                                                  |
# |[It will cost $50,000 per enrollee in Obamacare over the next 10 years.]                                                                         |[cost, $, 50,000, per, enrollee, Obamacare, next, 10, years, .]                                                                                             |[cost, 50,000, per, enrollee, Obamacare, next, 10, years]                                                                                          |
# |[The Federal Register - which houses all Washington regulations - is 34,000 pages in length and weighs in at more than 340 pounds.]              |[Federal, Register, -, houses, Washington, regulations, -, 34,000, pages, length, weighs, 340, pounds, .]                                                   |[Federal, Register, houses, Washington, regulations, 34,000, pages, length, weighs, 340, pounds]                                                   |
# |[]                                                                                                                                               |[]                                                                                                                                                          |[]                                                                                                                                                 |
# |[ in 1974]                                                                                                                                       |[1974]                                                                                                                                                      |[1974]                                                                                                                                             |
# |["Following the 2009 session,"" Texas House Speaker Joe Straus ""was acknowledged and 'thanked' for his 'tireless efforts' by Planned Parenthood]|[``, Following, 2009, session, ,, '', '', Texas, House, Speaker, Joe, Straus, ``, '', acknowledged, 'thanked, ', 'tireless, efforts, ', Planned, Parenthood]|[``, Following, 2009, session, '', '', Texas, House, Speaker, Joe, Straus, ``, '', acknowledged, 'thanked, 'tireless, efforts, Planned, Parenthood]|
# |["America was the ONLY country that ended"" slavery"]                                                                                            |[``, America, country, ended, '', '', slavery, '']                                                                                                          |[``, America, country, ended, '', '', slavery, '']                                                                                                 |
# +-------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# **Stemming**

# %%
from typing_extensions import Text
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('english')

def stemming(text):
  try:
    for words in range(len(text)):
      word=stemmer.stem(text[words])
      text[words]=''.join(word)
    return text
  except:
    return []

udf_stemming = udf(stemming, ArrayType(StringType()))

df = df.withColumn("stemmed_sentence",udf_stemming(F.col("filtered_sentence_1")))
df.select("id","statement","speaker","stemmed_sentence").show(10, truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------+------------------+--------------------------------------------------------------------------------------------------------------------------+
# |id                                                                                                                                                                                                |statement                                                                                                                                      |speaker           |stemmed_sentence                                                                                                          |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------+------------------+--------------------------------------------------------------------------------------------------------------------------+
# |21750                                                                                                                                                                                             |"Three doctors from the same hospital 'die suddenly' in the same week,"" after the hospital mandated a fourth COVID-19 vaccine for employees." |the gateway pundit|[, three, doctor, hospit, die, sudden, week, , , hospit, mandat, fourth, covid-19, vaccin, employe, ]                     |
# |18173                                                                                                                                                                                             |Say Joe Biden is a pedophile.                                                                                                                  |facebook posts    |[say, joe, biden, pedophil]                                                                                               |
# | "                                                                                                                                                                                                |24                                                                                                                                             |245               |[24]                                                                                                                      |
# |22673                                                                                                                                                                                             |A photo shows President Joe Biden and Ukrainian President Volodymyr Zelenskyy holding hands.                                                   |viral image       |[photo, show, presid, joe, biden, ukrainian, presid, volodymyr, zelenskyy, hold, hand]                                    |
# |9897                                                                                                                                                                                              |It will cost $50,000 per enrollee in Obamacare over the next 10 years.                                                                         |stuart varney     |[cost, 50,000, per, enrolle, obamacar, next, 10, year]                                                                    |
# |3855                                                                                                                                                                                              |The Federal Register - which houses all Washington regulations - is 34,000 pages in length and weighs in at more than 340 pounds.              |randy forbes      |[feder, regist, hous, washington, regul, 34,000, page, length, weigh, 340, pound]                                         |
# |Forbes previously served in Virginia's House of Delegates from 1989 to 1997 and in the State Senate from 1997 to 2001. He also was chairman of the Republican Party of Virginia from 1996 to 2001.|NULL                                                                                                                                           |NULL              |[]                                                                                                                        |
# |Forbes received a bachelor's degree from Randolph-Macon College                                                                                                                                   | in 1974                                                                                                                                       | in 1977."        |[1974]                                                                                                                    |
# |2884                                                                                                                                                                                              |"Following the 2009 session,"" Texas House Speaker Joe Straus ""was acknowledged and 'thanked' for his 'tireless efforts' by Planned Parenthood|abortion          |[, follow, 2009, session, , , texa, hous, speaker, joe, straus, , , acknowledg, thank, tireless, effort, plan, parenthood]|
# |18102                                                                                                                                                                                             |"America was the ONLY country that ended"" slavery"                                                                                            |facebook posts    |[, america, countri, end, , , slaveri, ]                                                                                  |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------+------------------+--------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows
